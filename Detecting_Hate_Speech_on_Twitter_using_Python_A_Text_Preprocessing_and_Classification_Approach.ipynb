# %% [markdown]
# # **Detecting Hate Speech on Twitter using Python: A Text Preprocessing and Classification Approach**
#
# Detecting hate speech is an important task for social media platforms in order to maintain a safe and respectful environment for all users. In this notebook, we explored a method to detect hate speech in Twitter data using Python. We first loaded a raw CSV file containing Twitter data into a Pandas dataframe, and then preprocessed the text data by removing URLs, HTML tags, punctuation, and stop words. We also applied stemming to the words in the text data.
#
# Next, we used the TextBlob library to classify the tweets as either positive, negative, or neutral, and then applied a custom rule-based approach to identify tweets that contained hate speech. We defined hate speech as tweets that contained offensive language, discriminatory terms, or harmful intent towards a particular group of people.
#
# By using this method, we were able to detect and flag potentially harmful tweets, which could then be reviewed by moderators to determine if further action was necessary. This approach could be further refined and applied at scale to help identify and mitigate the impact of hate speech on social media platforms.

# %%
# URL of the raw CSV file on GitHub
csv_url = "https://raw.githubusercontent.com/amankharwal/Website-data/master/twitter.csv"

# Make an HTTP GET request to the CSV URL
response = requests.get(csv_url)

# Parse the response text using the csv module
csv_reader = csv.reader(response.text.splitlines())

# Loop through each row in the CSV file
for row in csv_reader:
    # Do something with the row data
    print(row)
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# ['20223', '3', '0', '3', '0', '1', 'RT @oddfuckingtaco: Damn I hate a bitch that like to argue and shit']
# ['20224', '6', '0', '6', '0', '1', 'RT @oddfuckingtaco: https://t.co/nkCXCZwrXa my nigga really tried to save his bitch lol']
# ['20225', '3', '0', '3', '0', '1', "RT @odotkay: Mother's Day is n 16 mins. Y'all bitches picked y'all kids up from yo mama house so u can have 24hrs of custody n Instagram p&#8230;"]
# ['20226', '3', '0', '3', '0', '1', 'RT @officialbskip: I want a crazy bitch, they be loyal af &#128553;']
# ['20227', '3', '0', '3', '0', '1', 'RT @officialmckell: &amp; ima eat that pussy all filthy &#128525;']
# ['20228', '6', '2', '4', '0', '1', "RT @ogkaykay_: y'all hoes so annoying &#128530;"]
# ['20229', '3', '0', '3', '0', '1', 'RT @ogkels_: brought to you by bad bitches and good weed']
# ['20230', '3', '0', '3', '0', '1', 'RT @oh_sh1t: Damn, I got bitches *kanye voice*']
# ['20231', '3', '0', '3', '0', '1', "RT @ohhdatsbrucie: I can't be worried bout no bitch cause that bitch could be somewhere sucking dick"]
# ['20232', '3', '0', '3', '0', '1', "RT @ohhshedopee: I won't love you, I can't love youUnless that pussy got some super powers"]
# ['20233', '3', '0', '1', '2', '2', "RT @ohmyev: it's crazy. if a female cheats, it's so wrong. she's every type of hoe there is but if a guy cheats, there's all these justific&#8230;"]
# ['20234', '3', '0', '3', '0', '1', "RT @ohmyjizzitsliv_: You're the biggest cunt I know"]
# ['20235', '3', '0', '3', '0', '1', "RT @ohuhwhoops: Stacy's mom doesn't have shit going on.Twitter bitches have it all."]
# ['20236', '3', '0', '2', '1', '1', 'RT @oliviadesanfoot: this is very annoying to me im gonna vomit out of annoyance bc i am a little bitch']
# ['20237', '3', '0', '3', '0', '1', "RT @olmelonhead: bitches be acting different! &#128514; buuut it's cool! &#128129;"]
# ['20238', '6', '0', '6', '0', '1', 'RT @olmelonhead: when bitches spread rumors about you ; &#128520; https://t.co/21wOvyB50m']
# ['20239', '3', '0', '3', '0', '1', 'RT @omfgarsal: hoes be like "i\'m a virgin". http://t.co/NriPMCPnge']
# ['20240', '3', '0', '3', '0', '1', "RT @omfgarsal: kim kardashian is making $200 million from in app purchases from her game. and you all call her dumb, bitch she's a damn gen&#8230;"]
# ['20241', '3', '0', '3', '0', '1', "RT @omfgmeezy: maybe nobody likes you because you're a bitch"]
# ['20242', '3', '1', '2', '0', '1', 'RT @omfgmeezy: she stole my shit, what a little niglet.']
# ['20243', '3', '0', '3', '0', '1', 'RT @onDAT_Othershit: I swear, a yung nigga use to wanna be a heartbreak kid RT @_KudaBrazyy: Shawn Micheals &amp; Razor Ramon both had bitches']
# ['20244', '3', '1', '0', '2', '2', "RT @ooxlexx: I can't stand to be around ghetto girls.&#128134;"]
# ['20245', '3', '0', '3', '0', '1', 'RT @oroozco16: &#8220;@Tonymartinezz15: Some bitches need to get a life &#128175;&#128079;&#128524;&#8221;']
# ['20246', '3', '0', '3', '0', '1', 'RT @ortiz_jaylene: I\'m a "tall big booty bitch" wtf lol &#128557;&#128557;&#128557;&#128514;&#128514;']
# ['20247', '3', '0', '3', '0', '1', "RT @ortiz_jaylene: It's 2:20 and me and Bruno still up in this bitch lol"]
# ['20248', '3', '0', '3', '0', '1', "RT @ortiz_jaylene: Then I'm a loud outgoing bitch lol"]
# ['20249', '3', '0', '3', '0', '1', 'RT @ortizjunior_: First I need some pussy tonight &#128525;&#128166;']
# ['20250', '3', '0', '0', '3', '2', 'RT @osoplain: Soup is so much better when you have enough crackers to crumble in it to make it into a casserole']
# ['20252', '6', '1', '5', '0', '1', 'RT @ovgenocide: First off, fuck your bitch. And the click you claim.']
# ['20253', '3', '0', '3', '0', '1', "RT @oweeSheREDD: you tell ya business to ah bitch so I can't trust ya"]
# ['20254', '3', '0', '3', '0', '1', "RT @p0psson: &#8220;@iamlexj_: Lastnight &#128582;&#127825; #HalloweenCostume http://t.co/2UzOH6FRzG&#8221; hoe that's your work outfit"]
# ['20255', '3', '1', '0', '2', '2', 'RT @p_w_sterne: @GraceBr92073005 "There\'s more than one way to skin a monkey" --Barack "Bushmeat" Obama @1Dittlinger @Txwench']
# ['20256', '3', '0', '3', '0', '1', 'RT @paidinfull_4: &#8220;@brennonthekidd_: what would u do? .. &#128561; http://t.co/RisLnwWIeR&#8221;kick that bitch down the stairs!']
# ['20257', '3', '0', '3', '0', '1', "RT @paigelebeau1: It's unfortunate that everyone thinks I'm a bitch before they even meet me #chronicbitchface #sorryimscary &#128539;&#128513;"]
# ['20258', '6', '1', '2', '3', '2', 'RT @pambesteder: **WOW* according to this tweet by @Tarascan68 Obama must have been an Uncle Tom? http://t.co/Klcsgy9JPW']
# ['20259', '3', '0', '3', '0', '1', "RT @pandaapussy: The day I have clear skin will be the day I'm the happiest cockiest bitch alive"]
# ['20260', '3', '0', '2', '1', '1', 'RT @papichuIo: My soul mate probably some ho around the corner']
# ['20261', '3', '0', '2', '1', '1', "RT @papigabs: where's the girl I could pack this bowl with? I know u out there hoe, quit playing"]
# ['20262', '3', '1', '2', '0', '1', 'RT @papo_fonseca: Niqqas talk more then bitches these days.']
# ['20263', '3', '0', '3', '0', '1', "RT @patbeeh95: @iDocLyfe Rick James ain't even slap his bitches that hard"]
# ['20264', '3', '0', '0', '3', '2', "RT @pattonoswalt: Who spotted the looming yellow crown on tonight's #TrueDetective? http://t.co/MUa60ppVeL"]
# ['20265', '3', '0', '1', '2', '2', "RT @paul_lander: Charlie Sheen is engaged to a porn star. I can't be the only one thinking she can do a lot better."]
# ['20266', '3', '0', '0', '3', '2', 'RT @paul_lander: Yesterday, the caged bird sang the blues. RIP #MayaAngelou.']
# ['20267', '3', '0', '0', '3', '2', "RT @paulabruederle: Some birds aren't meant to be caged"]
# ['20268', '3', '0', '3', '0', '1', 'RT @paullowry42: @gingerash2013 lol and your response was bitch do I like pregnant?']
# ['20269', '3', '0', '3', '0', '1', "RT @paymon_d: Legendary year. RT @1stName_Bravo: Speaking of '09, that years pussy was phenomenal."]
# ['20270', '3', '0', '3', '0', '1', 'RT @peaceloveweed_: These hoes want my belvita http://t.co/DCVveTxeQ1']
# ['20271', '3', '0', '0', '3', '2', 'RT @peeabut: Dear god, make me a bird so I can fly far, far far away']
# ['20272', '3', '0', '3', '0', '1', 'RT @peeper1016: If preferring to be barefoot makes me a basic bitch, sign me up. Do I get a free Mason jar?']
# ['20273', '6', '0', '6', '0', '1', 'RT @peidroh: when you tell the chick-fil-a cashier thank you, but that bitch don\'t say "my pleasure" http://t.co/85swWYxMNz']
# ['20274', '3', '0', '0', '3', '2', 'RT @pekholt: Raven Symone\'s hair be like, "I\'m not colored, I\'m American." http://t.co/mkx0d4bh2Q']
# ['20275', '3', '0', '0', '3', '2', 'RT @pellucidstyles: they might be called 5 seconds of summer but their songs are 3 minutes of trash']
# ['20276', '3', '0', '3', '0', '1', "RT @petertrvjillo: Listen here you beautiful bitch, I'm about to fuck you up with some truth."]
# ['20277', '3', '0', '1', '2', '2', 'RT @pgammo: In the Yankees draft room, they had a huge picture of Greg Campbell with the message, "this is the makeup we\'re looking for."']
# ['20278', '3', '0', '0', '3', '2', 'RT @pgammo: Run Differentials:Mets -14, Yankees -32.']
# ['20279', '3', '0', '0', '3', '2', "RT @pgammo: That the Yankees have won four straight Shane Greene starts and 7 of 9 speaks to his stability in a season of starters' emergen&#8230;"]
# ['20280', '3', '0', '3', '0', '1', "RT @phatsyeo215: these bitches ain't real. &#128514;"]
# ['20281', '3', '0', '3', '0', '1', "RT @philiciaaaa: mcm &#128525;bc tomorrow's 6 months &#128152;Fuck everyone who said we wouldn't last. Proved you bitches wrong @tropicaldrew_ http://t.&#8230;"]
# ['20282', '3', '1', '2', '0', '1', 'RT @phishlicia: @tropicaldrew_ not about you fag. I miss you like crazy &#128553;&#10084;&#65039;']
# ['20283', '3', '0', '3', '0', '1', 'RT @phishlicia: Ocho is approaching bitches']
# ['20284', '3', '1', '2', '0', '1', 'RT @pipethefckdown_: People who focus on skin tones for dating someone are fucking retarded and brainwashed. &#128076;']
# ['20285', '3', '1', '2', '0', '1', 'RT @pissyopants1: Man robin thicke all on black tv trying to get that pussy back']
# ['20286', '3', '0', '3', '0', '1', 'RT @pocahontias__: Idc about yall bitches yo']
# ['20287', '3', '1', '2', '0', '1', 'RT @polarisclub: "im laughing so hard lay is the un-loyalist of hos"plea']
# ['20288', '3', '0', '0', '3', '2', 'RT @politico: Republican Rick Scott has been reelected #FLGov, defeating Democrat Charlie Crist. http://t.co/oeVMKOQH9S http://t.co/hi56c9N&#8230;']
# ['20289', '6', '0', '6', '0', '1', 'RT @poloPowell: All tha bad bitches need to go to @CurrenSy_Spitta concert in bham tonight. &#9992;&#65039;&#9992;&#65039;&#9992;&#65039;&#9992;&#65039;&#9992;&#65039;&#9992;&#65039;&#9992;&#65039;&#9992;&#65039;&#9992;&#65039;&#9992;&#65039;&#9992;&#65039;&#9992;&#65039;&#9992;&#65039;&#9992;&#65039;&#9992;&#65039;&#9992;&#65039;&#9992;&#65039;&#9992;&#65039;']
# ['20290', '6', '0', '0', '6', '2', "RT @pop_ruth: I'm a little teapot short and Irish @onedirection artist of the year #AMAs#EMABiggestFans1D http://t.co/9O1zfvlezV"]
# ['20291', '3', '0', '3', '0', '1', "RT @popitfor_tyrick: Bitch said I lie too much bitch you ain't worth telling the truth too"]
# ['20292', '6', '0', '6', '0', '1', 'RT @popitfor_tyrick: Tbh I left all my hoes alone &#128080;']
# ['20293', '3', '0', '3', '0', '1', 'RT @possiblydana: When bitches spread rumors about you https://t.co/6LVif0NuRf']
# ['20294', '3', '0', '3', '0', '1', 'RT @pound_Mytweets: "@wheeler_kashhh: http://t.co/PtQA8LZqEA" &#128525;&#128525;&#128525; we gave bitches something to be mad about . !']
# ['20295', '3', '0', '3', '0', '1', "RT @pppssshhh_: I be hatin when hoes be comin to me like I'm finna save them #aintnobread bitch u better get out here and get it"]
# ['20296', '3', '0', '3', '0', '1', 'RT @prettycha305: Monkey see &#128585;&#128584;monkey do hoes&#128586;']
# ['20297', '3', '1', '2', '0', '1', 'RT @prettychels__: I hate a dumb bitch.']
# ['20298', '3', '0', '3', '0', '1', 'RT @prettygrl_rocky: Pussy this pussy that']
# ['20299', '3', '0', '3', '0', '1', "RT @prettykells: &#8220;@100046729: @Leelucas_ @prettykells bitch you didn't feed me. You asked my to buy you a burger &#128514;&#128514;&#128128;&#8221;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514; lmfaoooooo no &#8230;"]
# ['20300', '6', '0', '6', '0', '1', 'RT @prettykells: &#8220;@100046729: @Leelucas_ bitch you not coming http://t.co/GXpfoLusXB&#8221;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;']
# ['20301', '3', '0', '3', '0', '1', "RT @prettykells: &#8220;@100046729: That's fucked up when a bitch you fw , down talk you.. Then with hoes they claim they don't fw &#128080; funny.&#8221;&#8252;&#65039;&#8252;&#65039;&#8230;"]
# ['20302', '3', '0', '3', '0', '1', "RT @prettykells: &#8220;@Leelucas_: @100046729 @prettykells lol bitch run ya bands up.. You know I'm dumb&#8221;I hate a broke bitch..... I hate em"]
# ['20303', '3', '0', '3', '0', '1', "RT @prettyne___: What you bitches fail to realize is these niggas don't really be moving on &#9995; they still be fucking with that SAME BITCH &#8252;&#65039;&#8230;"]
# ['20304', '3', '0', '3', '0', '1', "RT @prettytreazure: @DetroitPlayer @1stName_Bravo hey don't call him a bitch &#128074;"]
# ['20305', '3', '0', '2', '1', '1', "RT @prime13_time: Words from jac.. You can't save every hoe.. You got to let them hurt."]
# ['20306', '3', '0', '3', '0', '1', 'RT @prime3_time: @Woodchuck20 you about to get all the hoes now lol']
# ['20307', '3', '0', '3', '0', '1', "RT @pringlezXII: Dont message me your number and tell me to text you.... I'm not your bitch lol"]
# ['20308', '3', '0', '3', '0', '1', 'RT @pro_failure: My favorite childhood memory was when my mom found my stash of 30 Xanax then was slightly less of a bitch for exactly one &#8230;']
# ['20309', '3', '0', '0', '3', '2', 'RT @prolongshop: #LED #Christmas #decor Lights 10m 33ft 100 LED #Fairy string #Light for Outdoor/Indoor, http://t.co/2ew0jjhB6n']
# ['20310', '3', '0', '0', '3', '2', "RT @proofgelato: Sweet treat at lunch today - raspberry gelato, gin+juice sorbet &amp; brownie gelato! #GelatoCart Thursday - can't wait ..."]
# ['20311', '6', '1', '3', '2', '1', 'RT @psjohnson23: The problem with retard liberals is they think Supply &amp; Demand means "Supply me with everything I Demand." #VotingMatters']
# ['20312', '3', '0', '3', '0', '1', 'RT @pterosaur: Is Nick Jonas a hoe for squeezing his dick? Is Nick Jonas gonna have leaked nudes? Is Nick Jonas less of a role model?']
# ['20313', '6', '0', '6', '0', '1', "RT @pumpkinheaddd: &#128530; why these hoes acting like they not getting fucked &amp; sucking dick &#128080; but I ain't saying nothing &#128520;"]
# ['20314', '3', '0', '3', '0', '1', 'RT @que: I know u dawg hoes bck in style']
# ['20315', '3', '1', '2', '0', '1', 'RT @quecaine: white bitches love cocaine']
# ['20316', '3', '0', '3', '0', '1', "RT @queenallyssa: When your man call you a bitch when y'all arguing he don't think you really a bitch, you just actin like one"]
# ['20317', '3', '1', '2', '0', '1', "RT @queenalyzee_: We ain't friends hoe"]
# ['20318', '3', '1', '2', '0', '1', 'RT @queenc_nt: &#8220;@_100d: 90% of niggas goofy and act like bitches&#8221; YOU AINT LYIN']
# ['20319', '3', '0', '2', '1', '1', 'RT @queenthottie_x3: So proud of mahanain &#9825; she still a hoe tho']
# ['20320', '3', '0', '2', '1', '1', 'RT @quirkisms: Jeter to A-Rod. From class to trash.']
# ['20321', '3', '2', '1', '0', '0', 'RT @rachael_goss: Who wants to chill on campus w me &amp; throw bibles at bitches taking the walk of shame&#10067;&#10068;']
# ['20322', '3', '0', '1', '2', '2', "RT @radiomaru: nerds are cool because they get really judge-y about other nerds being passionate about things they aren't passionate abo ..."]
# ['20323', '3', '0', '0', '3', '2', 'RT @radiotour_en: Duchess of Cambridge to present the first yellow jersey http://t.co/8VVNU9DrFM #TDF']
# ['20324', '3', '0', '3', '0', '1', "RT @raejeanhightowe: &#8220;@Swuu_TheGod: Stop &#9995; playin bitch &#128589; you know I'm MVP &#127942;&#128526;&#8221;"]
# ['20325', '3', '0', '3', '0', '1', "RT @raeleenehoe: I hate it when a bitch know I don't fuck with her &amp; she really trying to talk to me like we cool nahh bitch foh you don't &#8230;"]
# ['20326', '6', '1', '4', '1', '1', 'RT @raider_level: She was like "I don\'t go to raider games. They are ghetto and people get jumped" lmao I was like "well the shit sound lik&#8230;']
# ['20327', '3', '0', '3', '0', '1', 'RT @random_shxt: need my dick sucked..fuck 1 bitch I need &#9996;&#65039; sluts']
# ['20328', '3', '0', '3', '0', '1', 'RT @randycaliboi: When I hear an ugly bitch talk about another ugly bitch &#128528; ... http://t.co/RwvyvPYE2n']
# ['20329', '3', '0', '3', '0', '1', "RT @randypop84: U bitches ain't paying my bills......so FUCK YOU"]
# ['20330', '3', '0', '0', '3', '2', 'RT @rappersaid: When Joey Bada$$ said "Traded in my Nikes for a new mic, I guess it\'s safe to say he sold his soles for a new life." http:/&#8230;']
# ['20331', '3', '0', '2', '1', '1', 'RT @rappersaid: When Tupac said "I ain\'t a killer but don\'t push me, revenge is the sweetest joy next to getting pussy." http://t.co/wL3mtG&#8230;']
# ['20332', '3', '1', '2', '0', '1', 'RT @rappersaid: When Tyler the Creator said "Rape a pregnant bitch and tell my friends I had a threesome." http://t.co/ImPo02Ge65']
# ['20333', '3', '1', '2', '0', '1', 'RT @rarebreedkena: shoutout to @OGMaco bitch you guessed it remix shit is &#128293;&#128293;&#128293;']
# ['20334', '3', '0', '3', '0', '1', 'RT @rasheed_wavy: @vivalakristia he bein a bitch']
# ['20335', '3', '0', '3', '0', '1', 'RT @rbomem: @viva_based broke, no even though Obama is working on it, bitch, no I got something between so no']
# ['20336', '3', '0', '0', '3', '2', 'RT @rcooley123: Bill Maher mocks gullible America for missing the real enemy http://t.co/ApnsVg35Uf']
# ['20337', '6', '2', '4', '0', '1', "RT @realist_iLLest: &#8220;@187XO_: Before I run from a niggah I'll lose the fight&#8221;"]
# ['20338', '6', '3', '2', '1', '0', 'RT @realist_iLLest: Mine too &#128513;&#128588;&#128076; RT &#8220;@187XO_: This ma niggah @trigga_tre123 &#128076;&#8221;']
# ['20339', '3', '0', '3', '0', '1', 'RT @realjonathanp: Bible RT @macktology101: You a hoe if you already got New Years Eve plans']
# ['20340', '3', '0', '3', '0', '1', 'RT @rebecca7054: &#8220;@CaitlinBartlett: yeah bitches http://t.co/2PP9RboHy4&#8221;']
# ['20341', '6', '0', '6', '0', '1', 'RT @rebelGANJA: &#8220;@1BookieG: Idk why I love skinny girls&#8221; they got good pussy &#9994;']
# ['20342', '3', '0', '3', '0', '1', 'RT @rebellious_midy: @wheeler_kashhh lol oh godddddd , bitch is you really coming &amp; how late you gon be lls']
# ['20343', '3', '0', '3', '0', '1', 'RT @rebellious_midy: Ugly bitches definitely disguste me &#128534; ewww yuck!']
# ['20344', '6', '0', '6', '0', '1', 'RT @redbonejasssy: She said I got to many hoes']
# ['20345', '3', '0', '3', '0', '1', 'RT @redemptionzayn: I inhale white exhale nigger']
# ['20346', '3', '0', '0', '3', '2', 'RT @reidk_97: Flappy bird is dusty']
# ['20347', '3', '0', '3', '0', '1', 'RT @relatabIe: i hate when people ask &#8220;who you tryna look good for?!&#8221; bitch myself bye']
# ['20348', '3', '1', '2', '0', '1', 'RT @relatabowl: bad bitches http://t.co/jz9ItvJck0']
# ['20349', '6', '0', '6', '0', '1', 'RT @rellyOnSMASH: that shoot em up shit is cool but gimme some shit i can play in front of bitches my nigga...gimme some jiggy shit i ca ...']
# ['20350', '3', '0', '1', '2', '2', 'RT @renegadecut: Video: Renegade Cut: Snowpiercer &#8212; An analysis of Bong Joon-ho&#8217;s sci-fi action film. Topics include... http://t.co/YNT9zS0&#8230;']
# ['20351', '6', '0', '0', '6', '2', 'RT @renz360: Got 5 20% off slots for sole sauce for the early birds today Use &#8220;SAVE20&#8221; at checkout  http://t.co/x5bq5vzpPK']
# ['20352', '6', '0', '0', '6', '2', 'RT @renz360: Got receipt ink on your soles? no problem. http://t.co/xYA7aLDUhU']
# ['20353', '3', '0', '3', '0', '1', 'RT @reshell_: "@1inkkofrosess: My ears look good &#128525;&#128525;&#128525;&#128525;&#128540;&#128541;&#128513; http://t.co/fP3R6mkBaC"bsa hoe in yo background']
# ['20354', '4', '1', '3', '0', '1', 'RT @reshell_: Keshun be like it aint nothing to cut that bitch nawl it aint &#128557;&#128514;&#128514;']
# ['20355', '3', '0', '1', '2', '2', 'RT @rhythmixx_: &#8220;@aliyahgrubb: Kanye West is a costume not a mock of a race.&#8221; girl I hate to do this but Kanye is a human not a costume but&#8230;']
# ['20356', '3', '0', '3', '0', '1', "RT @rhythmixx_: @Weyheymariam @jaymcnuggets that's how I drive you bitch http://t.co/drK5C0txtQ"]
# ['20357', '3', '0', '3', '0', '1', 'RT @riZkybiZneZZ: Joseline in the audience mad than a bitch']
# ['20358', '3', '0', '0', '3', '2', 'RT @richiesuavee: &#8220;@ViriDoesItt: Kevin Hart make funny faces.. His curriculum kinda trash..&#8221; Curriculum? &#128514;&#128514;&#128514; http://t.co/zJJyRGcZ9Y']
# ['20359', '3', '0', '1', '2', '2', 'RT @rickygervais: Have a great day, you lovely fellow apes :) http://t.co/jZL7filv0q']
# ['20360', '3', '0', '0', '3', '2', 'RT @rickygervais: Humans are genetically closer to chimps than chimps are to gorillas. But we are all apes. Have a great day you clever twe&#8230;']
# ['20361', '3', '0', '3', '0', '1', "RT @rickygervais: Jesus loves you, but everyone else thinks you're a right cunt."]
# ['20362', '3', '0', '2', '1', '1', 'RT @right_in_the: pussy']
# ['20363', '3', '0', '0', '3', '2', 'RT @rightwingertoo: Uh oh: California solar plant fries thousands of birds in mid-flight - Hot Air http://t.co/8ZQnLR5fH5']
# ['20364', '3', '0', '3', '0', '1', "RT @rihanna: I ain't got no type...bad bitches is the only thing that I like"]
# ['20365', '3', '0', '2', '1', '1', "RT @rihanna: Life's a bitch, but that's the only love I know"]
# ['20366', '3', '0', '0', '3', '2', 'RT @ripienaar: Fox News presenters mock female pilot who took part in campaign against Isis #wtf http://t.co/MLKY9ZSen2']
# ['20367', '3', '0', '3', '0', '1', 'RT @ripstephanie_: "let my shirt go bitch it\'s Aeropostale wtf is wrong with you " &#128514;&#128557;&#128514; https://t.co/xM5s5HN7tq']
# ['20368', '3', '0', '3', '0', '1', 'RT @roLLYuP23: When you deep in the pussy &#128514; http://t.co/3AtjdYqMnf']
# ['20369', '3', '1', '2', '0', '1', "RT @roach_nigga: &#8220;@XiaoBiniiMessy: Can't believe I actually killed a cockroach.&#8221; smh you a bitch, that was probably ma nigga Eduardo"]
# ['20370', '3', '1', '2', '0', '1', 'RT @roach_nigga: yall niggas think i just hang around your crib doing nothing, bitch i be getting bread too http://t.co/6jo2sayr96']
# ['20371', '6', '1', '5', '0', '1', 'RT @robdelaney: Girl I wanna rip my dick off and throw it at your pussy.']
# ['20372', '3', '0', '3', '0', '1', 'RT @robdelaney: I put my pants on one leg at a time, just like you guys. But then I eat a plus-size model&#8217;s pussy in my helicopter.']
# ['20373', '3', '1', '2', '0', '1', 'RT @robert4709: When u finger a bad light skin bitch http://t.co/jAzKccC9lE']
# ['20374', '3', '0', '0', '3', '2', "RT @robertbevan77: It's like The Walking Dead, but with less Carl and more talking birds. ZOMBIE ATTACK!!! http://t.co/UOCsPyksSC http://t.&#8230;"]
# ['20375', '3', '0', '3', '0', '1', 'RT @rockiefresh: If ya chick always getting into it wit other bitches u gotta tell her that shit ain&#8217;t fly, and it&#8217;s costly']
# ['20376', '3', '0', '3', '0', '1', 'RT @rod4short: Bitch must have a 279.0 &amp; be related to Jesus then {@TheBSharp: GPA or Legacy RT @The_Lion_: How this bitch get in http://t.&#8230;']
# ['20377', '3', '0', '3', '0', '1', 'RT @rodill_: niggas passing up good girls for hoes.']
# ['20378', '3', '0', '3', '0', '1', 'RT @rollieghost: &#8220;@vivalajayxoxo: Women would put up with very little love as long as the man have money..gross&#8221; bitches be with broke abus&#8230;']
# ['20379', '3', '0', '0', '3', '2', 'RT @ronele: Getting ready for Nevada Hump Day @nevadamuseum. Real live camels, ostriches and zebras - oh my! @VirginiaCity #NevadaHumpDay #&#8230;']
# ['20380', '3', '0', '3', '0', '1', 'RT @roryscovel: Surprising how big of a pussy Hulk is. #BRAvsCHI']
# ['20381', '3', '0', '3', '0', '1', 'RT @rose_shayna1: Never cared about how another bitch saw me. I know who I am']
# ['20382', '3', '0', '3', '0', '1', 'RT @rosestokoe: My bitch makes your bitch look like precious &#128109;&#128111;&#128150;&#128571; #thebooty #ohgawd #bae http://t.co/7FcCkRhxJI']
# ['20383', '3', '1', '2', '0', '1', 'RT @ruckin_andrew: This bitch has a death grip on this niggas balls. Smh http://t.co/uh6OSApcMw']
# ['20384', '3', '0', '0', '3', '2', "RT @runofplay: I'm confused. Martins Indi just drew a yellow card, but I didn't see him steal a tank from the Brazilian army and open fire &#8230;"]
# ['20385', '3', '0', '0', '3', '2', 'RT @russnelligan: .@KarynPolito declares victory by introducing "our next governor, Charlie Baker" @CharlieForGov #wcvb http://t.co/HYkWrVD&#8230;']
# ['20386', '3', '0', '0', '3', '2', 'RT @russnelligan: Final debate clean-up: journalists sure know how to trash a lobby... #wcvbpoli #wcvb http://t.co/LMerSj8sTi']
# ['20387', '3', '1', '2', '0', '1', 'RT @rustymk2: Not. A. Fucking. Charge. Even. As. A. Juvenile. If you call #MichaelBrown a thug at this point, just say "nigger" cuz it\'s &#8230;']
# ['20388', '3', '0', '0', '3', '2', "RT @ryancommakerry: I think it's time to bring out the drunken monkey"]
# ['20389', '3', '0', '3', '0', '1', "RT @ryancruz_: &#8220;@1waynostra: So jus don't be faithful cus u never kno what your bitch doing lmao&#8221;&#128514;&#128514;&#128514;&#128128;&#128128;&#128128;&#128553;&#128553;&#128514;&#128514;&#128128;&#128128;&#128128;&#128514;&#128553;&#128128;&#128128;&#128128;&#128514;&#128514;&#128128;&#128128;&#128128;&#128514;&#128514;&#128553;"]
# ['20390', '6', '0', '1', '5', '2', 'RT @ryancruz_: Travis always on my TL being ghetto &#128514;&#128514;']
# ['20391', '3', '0', '3', '0', '1', 'RT @ryancruz_: Want me to stamp bitches be saying anything to be down &#128564;']
# ['20392', '3', '0', '0', '3', '2', 'RT @ryandolan123: when people say coloured http://t.co/2lKUkctPf0']
# ['20393', '3', '0', '3', '0', '1', 'RT @ryannotsheckler: "That shit can break you down if you lose a good girl, I guess you need a bad bitch to come around and make it up"']
# ['20394', '3', '0', '3', '0', '1', 'RT @sTyLeZkEy354: Always bro niggas get crazy in any weather RT @WE_ALL_KNOW_JO: "@sTyLeZkEy354: This weather is trash" OD,But we gon get c&#8230;']
# ['20395', '3', '0', '3', '0', '1', 'RT @sTyLeZkEy354: How u talkin to hoes bout bronem?............why u talkin to hoes bout bronem?']
# ['20396', '3', '2', '1', '0', '0', 'RT @s_bitchy: Bitches be fallin so Inlove w. Niggass &amp; then he go get a new bitch &amp; they try go get a new nigga to try to forget about the &#8230;']
# ['20397', '3', '0', '3', '0', '1', 'RT @s_devante: That moment were u friend zone a bitch at 3am for calling u# do u now way time it is please gtf out my face#rich homie quan &#8230;']
# ['20398', '3', '1', '2', '0', '1', 'RT @sadaIlday: school is so pointless. im just trying to pass the class and get out this bitch']
# ['20399', '3', '0', '3', '0', '1', 'RT @sadiiex_: @Vnxthny I am taking you serious.... Kik me back nigger']
# ['20400', '3', '0', '3', '0', '1', 'RT @sadiiex_: @x_NWTS answer you phone hoe, I heard boutcha']
# ['20401', '3', '3', '0', '0', '0', "RT @salmeron_bryan: You're not the father ! What every Mexican/nigger loves to hear."]
# ['20402', '3', '0', '3', '0', '1', 'RT @salomanizor: Kick her in the cunt']
# ['20403', '3', '2', '1', '0', '0', 'RT @salomanizor: Too many faggots on here that think they can address me by my first name']
# ['20404', '3', '0', '3', '0', '1', 'RT @samAfuckingA: I wish I was a bird so I could constantly shit on the people I hate! :)']
# ['20405', '3', '0', '0', '3', '2', "RT @samknight1: @EliLake @saletan @JeffreyGoldberg Yeah I know it's Jeff's book. The one where he admits to beating prisoners and lying abo&#8230;"]
# ['20406', '3', '0', '2', '1', '1', 'RT @samzbikowski: @TonyJRodriguez dude I had a video of these birds at my work fuckin']
# ['20407', '3', '0', '3', '0', '1', "RT @sangelina_xo: what's with guys and fat bitches I will clearly never understand"]
# ['20408', '3', '0', '3', '0', '1', "RT @santos_brina: I could never mess around with someone else's man, like that's just clarifying your self as a side hoe."]
# ['20409', '3', '2', '1', '0', '0', 'RT @saramariewelch: Been my main nigguh since digital camera selfies @thorpe_emily http://t.co/XiQiRbQ7mP']
# ['20410', '3', '0', '3', '0', '1', "RT @saramariewelch: Can't mean something to someone when they hittin up Otha bitches"]
# ['20411', '3', '0', '3', '0', '1', 'RT @saraschaefer1: Can you get eye cancer from reading too many Michael Douglas pussy-juice-throat-cancer jokes?']
# ['20412', '6', '2', '4', '0', '1', 'RT @sarcassmlol: &#8220;jinkies i lost my glasses!&#8221; - velma in every fucking episode of scooby doo like damn bitch get contacts']
# ['20414', '3', '0', '3', '0', '1', "RT @sassy_cee_: What y'all hoes up to?"]
# ['20415', '4', '0', '1', '3', '2', 'RT @sassytbh: a girl tweeted "you might be ghetto if u bring food from outside into the movies"no u might be stupid if u pay 4.99 for a b&#8230;']
# ['20416', '3', '0', '3', '0', '1', 'RT @saucygyro: @_WhitePonyJr_ ugly bitch has blood on her hands for her whore ways']
# ['20417', '3', '0', '3', '0', '1', 'RT @savannacurry_: yelling my feelings about self centered not to think for themselves bitches is gr8']
# ['20418', '3', '1', '2', '0', '1', 'RT @savethesehos: If I ride up to your bitch in these then...homie consider yourself a single nigga . http://t.co/RJAiohrPhw']
# ['20419', '3', '0', '2', '1', '1', 'RT @savethesehos: Your bitch when my Skechers light up . http://t.co/vqLUSPYqmO']
# ['20420', '3', '0', '3', '0', '1', 'RT @savingthesehoes: bitch text me goodmorning first, or something.']
# ['20421', '3', '0', '3', '0', '1', 'RT @sbacilio1224: Neta bullshit aside I need to get me a bad bitch']
# ['20422', '3', '3', '0', '0', '0', 'RT @sblmnl_crmnl: @woods_lamar shut your nigger ass, lamar']
# ['20423', '3', '1', '2', '0', '1', "RT @scaffoldjocky: I'll never smoke weed with Willy again. He invited that hick, Toby Keith, and I fucking hate that mongoloid!"]
# ['20424', '3', '1', '2', '0', '1', 'RT @schooIgirI: I say nigger with love']
# ['20425', '3', '0', '3', '0', '1', 'RT @schoolfession: "Bros before hoes, except chicks with no clothes" - Everywhere']
# ['20426', '3', '0', '3', '0', '1', 'RT @schoolfession: "My ex girlfriends telling people I sell pills and coke. Retweet if she\'s a bitch." - Durant HS']
# ['20427', '3', '0', '2', '1', '1', 'RT @scott1023: "I said thin mints bitch". http://t.co/yRVQjxeyqO']
# ['20428', '3', '0', '0', '3', '2', "RT @scottiken: It's settled. The Ding Dong is far superior than the Twinkie."]
# ['20429', '3', '0', '0', '3', '2', 'RT @scottvtracy: @AbuYazidMuawiya @amustafaanbari1 Congratulations for reinforcing the stereotype for insecure, uneducated, uncivilized, ba&#8230;']
# ['20430', '3', '1', '2', '0', '1', 'RT @scotty160: I blatantly believe that men look creepy as shit with a ghetto ass mustache']
# ['20431', '3', '0', '3', '0', '1', 'RT @scottydoesntN0: Cinco De mind yo own damn business, bitch']
# ['20432', '3', '1', '2', '0', '1', 'RT @scressful: @DFkinLopes LMfAOOO this bitch tongue longer than some niggas dicks']
# ['20433', '3', '0', '1', '2', '2', "RT @seanmdav: Since I know you're wondering, @blakehounshell: No, Cracker Barrel is not a place to buy barrels full of crackers."]
# ['20434', '3', '0', '3', '0', '1', "RT @seansteiger31: I don't gang bang ho, I jus gang bang these hoes &#128299;"]
# ['20435', '3', '0', '3', '0', '1', 'RT @seansteiger31: Melo will be a bitch if he leaves, and well Lebron is jus a bitch regardless lol']
# ['20436', '3', '0', '2', '1', '1', 'RT @seansteiger31: Sometimes I listen &amp; revisit them old albums often as I can &amp; skim through all them bitches to make sure I keep up with &#8230;']
# ['20437', '3', '0', '3', '0', '1', 'RT @semper_fiibitch: Farra from teen mom has 2 sex tapes on pornhub lmao hoe ass']
# ['20438', '3', '0', '0', '3', '2', 'RT @sepinwall: Day 2 of FXX&#8217;s Simpsons marathon &#8212; &#8220;Bart&#8217;s Dog Gets an F&#8221; to &#8220;Last Exit to Springfield&#8221; &#8212;&#160;will be the best consecutive 24 ho&#8230;']
# ['20439', '3', '0', '3', '0', '1', 'RT @shabbashone "@ThoughtsOfRandy: I almost ran this fine red bitch over." Damn + lol']
# ['20440', '3', '0', '2', '1', '1', 'RT @shaelynspacyyy: &#8220;@UglyAssDerrick: @shaelynspacyyy they trash though?&#8221; http://t.co/dJ5kvo7RSr']
# ['20441', '3', '0', '1', '2', '2', "RT @shakiraevanss: Criticize Amanda for saying the n word, sure, but don't make jokes about her sexual assault, don't be trash."]
# ['20442', '3', '0', '3', '0', '1', 'RT @shananigans__: 50 shades of shut your bitch ass up']
# ['20443', '3', '0', '3', '0', '1', 'RT @shanequabullock: Meet me and my bitches @ #MansionElan']
# ['20444', '3', '0', '3', '0', '1', "RT @shantelb_: &#8220;@WeAre_XCI: I know bitches who sell pussy for 3.5's&#8221; &#128514;&#128514;&#128514;"]
# ['20445', '3', '0', '3', '0', '1', 'RT @shantybear: bitch do I entertain you? Cause you always seem to be in my business']
# ['20446', '3', '0', '3', '0', '1', 'RT @shardae85yahoo: Jessica ass dont need no more liquior !!!! when the bitch drinks she forgets everything the very next day ! it never fa&#8230;']
# ['20447', '3', '0', '3', '0', '1', "RT @shayconnnor: u ain't sailor moon bitch"]
# ['20449', '3', '3', '0', '0', '0', 'RT @sheemteam97: Fuck the Islamic State!! We will kill those cunts&#127468;&#127463;']
# ['20450', '6', '0', '6', '0', '1', 'RT @shelbieperdue: Instagram needs to stop being a bitch!']
# ['20451', '3', '0', '3', '0', '1', 'RT @shikeattike: I hate a bitch that constantly call herself ugly. That shit is so annoying man']
# ['20452', '3', '0', '3', '0', '1', "RT @shikeattike: Nah bitch you ain't just gone go off on me and just want me back 5 minutes later. I'm playing 2k until further notice"]
# ['20453', '3', '0', '3', '0', '1', "RT @shikeattike: Pussy niggas don't get no pussy nigga"]
# ['20454', '3', '0', '2', '1', '1', "RT @shikeattike: When the neighborhood freak throw you some pussy and you don't catch it http://t.co/koLoObmVfa"]
# ['20455', '3', '0', '3', '0', '1', 'RT @shitballshonkey: I watched my followers drop like flies when they started seeing shit that made them upset lol take salt bitch']
# ['20456', '3', '0', '3', '0', '1', "RT @shonni__: My momma talm bout 'these kids party more than their parents ' &#128530; TF duh, why would you think it's ok for you to pussy pop at &#8230;"]
# ['20457', '3', '0', '3', '0', '1', 'RT @shoulder_LEEN: &#8220;@intentions_: New York bitches be like #ThatNYCshit #bitchesbelike #newyorkGirlsbelike #hoodbitches LMFAOO&#128514;&#128514; &#128514; https:/&#8230;']
# ['20458', '3', '0', '0', '3', '2', "RT @sickipedia: I drove my daughter's guinea pig to the vet's this morning. I'm quite handy with my new Callaway golf clubs.#sickipedia"]
# ['20459', '3', '1', '2', '0', '1', 'RT @sidneeyrosee: fuckin skyler white is such a bitch']
# ['20460', '3', '0', '3', '0', '1', 'RT @silent_musings: Happy Monday bitches. Just wanted you to know, "yes you can" Don\'t ever fucking forget how amazing and strong you are.']
# ['20461', '3', '0', '3', '0', '1', 'RT @silent_musings: Over-thinking can and will fuck up the simplest things. Lighten up bitches.']
# ['20462', '3', '0', '3', '0', '1', 'RT @simplyalize: "@xonayyy: &#8220;@ugglyyy: well ain\'t this bout a bitch ... http://t.co/CVJadMYpg6&#8221; &#128514;&#128514;&#128514;" BRUH&#128553;&#128514;&#128514;']
# ['20463', '3', '0', '0', '3', '2', "RT @simplyforkicks: Quan helps everyone out with random questions and computer stuff but no one can oop him GRs?! Something ain't right abo&#8230;"]
# ['20464', '3', '0', '3', '0', '1', "RT @sisssyhaymaan: If you brush off a guys compliment just because you have a boyfriend, you're a bitch"]
# ['20465', '3', '0', '2', '1', '1', 'RT @skankymunter: Pissed in shower, now checking for yellow legs.']
# ['20466', '3', '0', '0', '3', '2', 'RT @skullmandible: Now Call Down Your Dark and Your Cold and Be Damned, Charlie Brown']
# ['20467', '6', '0', '0', '6', '2', 'RT @sky106radio: For lots of great oldies, check out "Memories and More", with Yankee Rose, today from 1:00 PM to 4:00 PM Eastern! http://t&#8230;']
# ['20468', '3', '0', '3', '0', '1', 'RT @skyereyes_: &#8220;@Feebito_23: Lol this is why I don\'t fuck with so many bitches&#8221;don\'t call her a "bitch"']
# ['20469', '3', '0', '3', '0', '1', "RT @skyereyes_: &#8220;@GinaSanabria_: I have no hoes man. I don't need those though &#128564;&#8221;&#128557;&#128557; I need to pick mines back up &#128553;"]
# ['20470', '3', '0', '3', '0', '1', 'RT @skyereyes_: &#8220;@InspireNaima: Text someone "That pussy was so good!" &amp; "Sorry, wrong number" and quote this with their response.&#8221;&#128514;&#128514; http:&#8230;']
# ['20471', '3', '0', '3', '0', '1', "RT @skyereyes_: If that's what makes these fat bitches sleep at night &#128564;"]
# ['20472', '3', '0', '3', '0', '1', "RT @slbgng_eddie: &#8220;@cristinacetino: @slbgng_eddie shit nigga don't complain. Now you got room for hella nudes from hoes&#8221; Trueeee, I'll hy&#8230;"]
# ['20473', '3', '1', '2', '0', '1', 'RT @slbgng_eddie: &#8220;@white_thunduh: On boys im a retard sometimes&#8221; all the time *']
# ['20474', '3', '0', '3', '0', '1', 'RT @slbgng_eddie: @white_thunduh bitch spoil me']
# ['20475', '3', '1', '2', '0', '1', 'RT @slimthugga: U a nurse &#128514;RT @Blaccstone: @slimthugga you a clown boy You music is trash.... I dare you say something back I bury your Bit&#8230;']
# ['20476', '3', '0', '3', '0', '1', 'RT @slinkjohnson: I think Imma patent disposable douche, in ketchup type packages. Bitches can be sanitary and discreet. For the hoe on-the&#8230;']
# ['20477', '3', '1', '2', '0', '1', 'RT @slllick_: Trey Songz reply to Nicki Minaj &gt;&gt;&gt;&gt; ... That nigga spoke the truth on looking ass bitches lmao ... I knew someone was gonna &#8230;']
# ['20478', '3', '0', '0', '3', '2', 'RT @sluggernation: The P72 Derek Jeter used to hit the walk-off single in his final @Yankee Stadium at-bat. (Images via @mlb_authentic) htt&#8230;']
# ['20479', '3', '0', '3', '0', '1', 'RT @smithmuffins: once at a gradeschool dance i tried to do the worm to impress this bitch and i slammed my dick on the unforgiving ceramic&#8230;']
# ['20480', '3', '0', '3', '0', '1', "RT @snoleezey801: @uce_INA poly ratchets.. Can't stand poly bitches in general &#128514; they loud, annoying, and they talk too much.."]
# ['20481', '3', '1', '2', '0', '1', 'RT @socass_: &#8220;@00sexilexi00: @socass_ I SANG FOR YOU, YOU NAZI&#8221;*beaner']
# ['20482', '3', '0', '3', '0', '1', 'RT @sofancyy_: A hoe gone be a hoe &#128564;']
# ['20483', '6', '0', '6', '0', '1', "RT @sofancyy_: Swear these hoes ain't got nothing on me &#128107;&#128129;"]
# ['20484', '3', '0', '3', '0', '1', 'RT @sofpizzie_: i hate a bitch that think she the shit, bitch you basic as the fuck&#128564;&#128564;']
# ['20485', '3', '0', '1', '2', '2', 'RT @sofuckingSwazye: "mayonnaise colored benz i push miracle whips" http://t.co/BmXuyP8ehH']
# ['20486', '3', '0', '3', '0', '1', 'RT @sonup_qp: Llamf cumin wit better bars already bitch boiz &#128529;&#128529;&#128529;&#128529;&#128529; yall dun fukd all da way up']
# ['20487', '6', '1', '1', '4', '2', 'RT @sorryimalex: "now 5sos is starting to tweet the hashtag, they\'re trash!" #vote5sos http://t.co/llkuz6VtAi']
# ['20488', '6', '0', '1', '5', '2', 'RT @sorryimalex: &#8220;@lametears: i only rted alex ramos aka trash to gain followers&#8221; #vote5sos']
# ['20489', '3', '3', '0', '0', '0', "RT @sorryimalex: I got called a faggot for buying girl toms so now I'm gonna fuck that person in the ass"]
# ['20490', '3', '0', '0', '3', '2', "RT @sorryimalex: I'm only back cause I don't wanna see the boys lose to trash #vote5sos"]
# ['20491', '3', '0', '2', '1', '1', "RT @sorryimalex: idkmadz tbh I've seen you in recess at the monkey bars but I was too busy getting beat up lol ! we should talk more! rate &#8230;"]
# ['20492', '3', '0', '3', '0', '1', 'RT @souljaboy: @kmichelle beef? Bitch ur pussy smell like beef &#128169;&#128514;&#128514;&#128514;']
# ['20493', '3', '0', '3', '0', '1', 'RT @souljaboy: @kmichelle crank that shitty pussy yuuuuuuuuuaaaaaaa &#128169;&#128169;&#128169;&#128169;&#128169;&#128169;&#128169;&#128169;']
# ['20494', '3', '1', '2', '0', '1', 'RT @souljaboy: @kmichelle ur pussy smell like dumpster juice &#128169;']
# ['20496', '3', '0', '3', '0', '1', "RT @souljaboy: Ain't got time for stupid bitches &#128557;"]
# ['20497', '3', '0', '3', '0', '1', 'RT @souljaboy: K Michelle pussy smell like shit']
# ['20498', '3', '0', '0', '3', '2', 'RT @southernshirt: The only things you need in life are comfy shirts and Oreos #southernshirt']
# ['20499', '4', '0', '4', '0', '1', 'RT @spiffytwiley: @vintage_monroe_ bitch you gorgeous']
# ['20500', '3', '0', '3', '0', '1', 'RT @splitsecond84: I got Twitter, Facebook, &amp; Instagram.. The Fuk Yuh Mean "send u a pic ?.. bitch you better Download my avi']
# ['20501', '3', '0', '0', '3', '2', "RT @sportspickle: Yankees didn't want Russell Martin, so he signed with the Pirates 2 years ago. Pirates have made back-to-back postseasons&#8230;"]
# ['20502', '3', '0', '0', '3', '2', 'RT @sportswithjohn: Dani Alves uses his new gray hair to talk himself out of a yellow card, telling the referee, "I am but a humble senior &#8230;']
# ['20503', '3', '0', '0', '3', '2', "RT @spurs: It's a bird...It's a plane...It's SuperManu #NBASuperHeroes"]
# ['20504', '3', '0', '3', '0', '1', "RT @squarebutts: Don't got a problem smacking a bitch"]
# ['20505', '3', '0', '3', '0', '1', 'RT @squeakkgod: Fuck da Opps 1x Fuck dear hoes 3x &#128514;']
# ['20506', '3', '0', '0', '3', '2', "RT @ssbeirne: It's a bird! It's a plane! It's a boat! No...It's, it's... a flying human? #lakeerie #cle http://t.co/TTL10nqBzJ"]
# ['20508', '3', '0', '3', '0', '1', 'RT @starzz2929: I wanna be the reason u look down at your phone &amp; smile then a car run yo ass over hoe!']
# ['20509', '3', '0', '3', '0', '1', 'RT @stayclassay: Paybacks a bitch it really is!']
# ['20510', '4', '0', '4', '0', '1', "RT @stayfoqused: Don't eat pussy until she show you the Vagfax"]
# ['20511', '3', '0', '3', '0', '1', 'RT @steph_dcx: Fucking nosey ass bitch I swear lol']
# ['20512', '3', '0', '3', '0', '1', 'RT @stephanielazox: Hope you got what you wanted bitch.']
# ['20513', '3', '2', '1', '0', '0', "RT @stepheeezyy: Rt *nigga *bitch *him &#8220;@187XO_: ' I will never date a female with another niggah name on her lol . Wtf .&#8221;"]
# ['20514', '3', '0', '0', '3', '2', "RT @stephpaulus: I have yet to master the art of eating a powdered donut without looking like I just left Charlie Sheen's house."]
# ['20515', '3', '0', '3', '0', '1', "RT @steveersh: I'm a star jones man myself, I love that big bitch"]
# ['20516', '3', '0', '1', '2', '2', 'RT @steviegarcia11: Here come wiggas soft tweets.. &#128514;']
# ['20517', '3', '0', '3', '0', '1', 'RT @stillandru: White ppl will call Mexicans beaners and claim they taking their jobs but have sugar skull tattoos :-(']
# ['20518', '3', '1', '0', '2', '2', 'RT @stoolpresidente: If a tree falls in the woods and nobody is around does it make any noise? If NJ blows away and only trash live the ...']
# ['20519', '6', '0', '6', '0', '1', "RT @strapdafool: Naw deez ain't no 24s hoe u gota add 4 mo ...#str8up"]
# ['20520', '3', '0', '3', '0', '1', 'RT @stripsofgabby: &#128514;&#128514;&#128514;&#128128;&#8220;@SouthsideVic: My stroke game stale so I gotta eat the pussy like a husky dike.&#8221;']
# ['20521', '3', '0', '0', '3', '2', 'RT @studio6263: M&amp;S bids for most social Christmas yet with &#8216;Follow the Fairies&#8217; campaign http://t.co/5OaL2EHhG2 #CLE #marketing']
# ['20522', '3', '0', '3', '0', '1', "RT @suckdisdpiece69: I'm gonna rock out with my cock out, and you're gonna jam out with your clam out"]
# ['20523', '4', '0', '3', '1', '1', 'RT @sugaarCanee: Hoes be like "go talk to one of your hoes".... I be like "you are one of my hoes"']
# ['20524', '3', '0', '3', '0', '1', 'RT @summerdawn_1996: @Trestin_Galore_ I know cunt nugget &#128514;&#128514;']
# ['20525', '3', '0', '0', '3', '2', 'RT @supercos7: @peddoc63 @Cavemaninc @CarmineZozzora @DB103173 Charlie understood &#128299; how to keep those percentages &#128201; lower.. http://t.co/&#8230;']
# ['20526', '3', '0', '3', '0', '1', 'RT @surviving_queen: her pussy stay wet when shes around me gotta lick it till she wetter then never before']
# ['20527', '3', '0', '3', '0', '1', 'RT @sweatercamila: lohanthony is such a little bitch he doesnt even like the girls and he gets followed i dedicate my life to them and i ge&#8230;']
# ['20528', '3', '0', '3', '0', '1', 'RT @sweetalliee: a loyal girl really truly does come with a smart mouth and arguments. only a hoe will let you do as you please cause she g&#8230;']
# ['20529', '6', '0', '0', '6', '2', 'RT @sweetromance: @1visionamd @Redeemed1952 @AZWS Once again, birds of a feather....']
# ['20530', '6', '0', '0', '6', '2', 'RT @syd_renae: @2014Alyssa I have a pink fuzzy one &amp; a silky silver one. Bathrobes are a wonderful thing &#128129;&#128526;&#128525;']
# ['20531', '3', '0', '3', '0', '1', 'RT @sydneysoleil: Spider-Man was a bitch highkey tho']
# ['20532', '3', '0', '0', '3', '2', 'RT @sydswag2: Buy me double stuffed Oreos and you can be my boyfriend']
# ['20533', '3', '0', '3', '0', '1', 'RT @tKOs_way: Cumming in her pussy was love']
# ['20534', '3', '0', '3', '0', '1', 'RT @t_grun: Yeah I checked my connection, I have fucking wifi. Did you check if you were being a lil bitch nigga? http://t.co/0kvF0REwjd']
# ['20535', '3', '0', '0', '3', '2', 'RT @tableninemutant: So City Lights is a Charlie Chaplin movie by @007hertzrumble http://t.co/qYN1Bc7MxS via @wordpressdotcom']
# ['20536', '3', '0', '3', '0', '1', "RT @taexchanae: momma dee ain't loyal. you ain't pose to tell his main bitch bout his side bitches &#128514;"]
# ['20537', '9', '2', '6', '1', '1', 'RT @tailorlamar: yall niggas is hoes.']
# ['20538', '3', '0', '3', '0', '1', 'RT @takeyaah: when his hoes thought it was over: http://t.co/jhaOcX1MTd']
# ['20539', '3', '0', '3', '0', '1', "RT @tanajiamonay_: i hate hype ass bitches, like ... it's too early for you to be all loud; sit tf down somewhere."]
# ['20540', '3', '0', '3', '0', '1', 'RT @tanaka_callen: @t_ndyy awwww my niggar thank you so much sure means a lot &#9825;&#9825;']
# ['20541', '3', '0', '3', '0', '1', "RT @tanishalixpussy: no need to compete with other women there's only one of me, and shit... im that bitch"]
# ['20542', '3', '2', '1', '0', '0', 'RT @taylor_TM: @PacmanJonez @PhilWOTG you the whitest person on my TL but you always so ghetto. Im sick of it']
# ['20543', '3', '0', '0', '3', '2', 'RT @taylorcaniff: I wear beanies all winter long! So no bandanas till summer&#128525;']
# ['20544', '3', '0', '0', '3', '2', "RT @taylorcaniff: I'm having a date at Yankee Field then getting kiss cam.. #bucketlist"]
# ['20545', '6', '0', '6', '0', '1', "RT @taylorlopez96: &#8220;@harleighpurolla: You are the biggest two faced bitch I have ever met.&#8221; You won't @ her"]
# ['20546', '3', '0', '3', '0', '1', "RT @taylormrake: People beg to see women's bodies but the minute they're seen that woman is now a hoe oh okay"]
# ['20547', '3', '0', '3', '0', '1', "RT @taylorrDiane: When a sideline hoe gets mad, BITCH SHUT UP! You was okay with being second ALL this time, now all of sudden it's a probl&#8230;"]
# ['20548', '3', '0', '3', '0', '1', 'RT @taymaeGOTEM: Bitches tweets be like..."I wanna suck some dick &#127814;" then be like..."&#9995; Chill it\'s just a song! " bitch what song is&#8230;']
# ['20549', '3', '0', '3', '0', '1', 'RT @taymy_: I be so confused when y\'all be tweeting "I wanna bitch that can roll my weed &amp;smoke all night with" like wtf kind of standards &#8230;']
# ['20550', '3', '1', '2', '0', '1', 'RT @taypaynay: Little bitch']
# ['20551', '6', '0', '6', '0', '1', 'RT @taysymonee: @1inkkofrosess that hoe so icy&#128557;&#128293;']
# ['20552', '3', '0', '2', '1', '1', 'RT @taysymonee: Some of you hoes got so much to say with so little&#128134;']
# ['20553', '3', '0', '3', '0', '1', 'RT @tbhbooty: Latina pussy be like http://t.co/VORy1vgH4U']
# ['20554', '3', '0', '3', '0', '1', 'RT @tbhjust: "what are you twelve"yeah on a scale of one to tenbitch']
# ['20555', '3', '0', '0', '3', '2', 'RT @tbhjuststop: my score on flappy bird is higher than the broncos score right now']
# ['20556', '6', '0', '6', '0', '1', 'RT @tbhjustzach: why be negative when you can be positive fucking smile you beautiful bitch']
# ['20557', '3', '1', '2', '0', '1', 'RT @tcaputo44: Trust no bitch #wordsofadvice']
# ['20558', '3', '0', '0', '3', '2', 'RT @teapot: Stuff broke loose, must not panic and share GIF instead http://t.co/JL4GuIeJ84']
# ['20559', '3', '0', '3', '0', '1', 'RT @teeaduh: "so many hoes, it should be an ethnicity"']
# ['20560', '3', '0', '3', '0', '1', 'RT @teekaydont_GAF: @WestSideFlee out here sending hoes clean off fse !!!!&#128514;&#128514;&#128514;&#128514;']
# ['20561', '6', '0', '6', '0', '1', 'RT @tekiaa_: I wasnt put on earth for a bitch not to like me&amp; I damn for sure dgaffff &#128540;&#128076;']
# ['20562', '3', '0', '0', '3', '2', "RT @terri_georgia: Charlie Crist Leads Rick Scott In a Florida Governor's Race Where Every Vote Will Matter http://t.co/FWUH5pVnjk"]
# ['20563', '3', '0', '2', '1', '1', "RT @tf_i_looklike: Bae: If I win you don't get no pussy tonight Me: Shiiiiiit... &#128514;&#128514; http://t.co/yUJJDMtDC4"]
# ['20564', '3', '0', '0', '3', '2', 'RT @th3j35t3r: Prime suspect of #Foley murder is 23y/o British Jihadi who, wait for it ... "declared his allegiance to Anonymous\'" http://t&#8230;']
# ['20565', '3', '0', '3', '0', '1', 'RT @thaboyrich: &#128073;&#128073;RT @NYSAnimal It used to be a shame to be hoe/prostitute, with social media they call it hustling lol']
# ['20566', '3', '0', '1', '2', '2', 'RT @thachosenkid321: @DonQuixtote he trash tbh #StartMikeVike']
# ...
# ['25136', '3', '0', '2', '1', '1', 'u lucky he holdin me back bitch http://t.co/HanER6B9Ts']
# ['25137', '4', '0', '4', '0', '1', 'u sent nudes when ina relationship or nah? "@JazmineJanay_: Her pussy bleeding or nah? "@GraePharoah: -_- http://t.co/W9ZPJfk93r"']
# ['25138', '6', '0', '6', '0', '1', 'u should be here wit me bitch']
# ['25139', '6', '0', '6', '0', '1', 'u stupid bitch']
# ['25140', '3', '1', '2', '0', '1', 'u that nigga RT @Charmin_Harmon I have no idea how random jiggas be knowing my name at work smh.']
# ['25141', '3', '0', '3', '0', '1', 'u want a cookie tomorrow bitch @_lostb0y']
# ['25142', '3', '0', '3', '0', '1', 'u-bitch-u']
# ['25143', '3', '0', '3', '0', '1', 'ugh&#8230; the bitch name was Leather&#8230;']
# ['25144', '3', '0', '3', '0', '1', 'ugly hoe']
# ['25145', '3', '0', '0', '3', '2', 'under my windoowww &#8220;@brettcanfly: Bleaching your teeth, smiling flash, talking trash, under your breath&#8221;']
# ['25146', '3', '0', '2', '1', '1', 'ur trash! http://t.co/6KN7PzTgl8']
# ['25147', '3', '0', '0', '3', '2', 'versace bird feeder']
# ['25148', '3', '0', '3', '0', '1', 'waaaaay too many niggas comfortable wit dressing up like ugly bitches for IG likes an re-posts....']
# ['25149', '3', '0', '3', '0', '1', 'wack bitches make me curve them']
# ['25150', '3', '0', '0', '3', '2', 'walking dead gonna be so trash this season']
# ['25151', '3', '0', '3', '0', '1', "walking down the st and this girl with a guy past me and the girl says I'm bout to turn dyke for her ctfuu classic"]
# ['25152', '4', '1', '3', '0', '1', 'wallah I fucking hate this fuckin mexican bitch so much.']
# ['25153', '3', '0', '3', '0', '1', 'wanna make a boss happy? &#128527;bitch talk nasty. &#128540;']
# ['25154', '3', '1', '2', '0', '1', 'want to catch my attention niggah throw up a dolla sign']
# ['25155', '3', '0', '3', '0', '1', 'was just informed that "crunk ain\'t dead ho!"&#8230; lol okay sure']
# ['25156', '3', '1', '2', '0', '1', 'watch out for these foul hoes and flagrant niggas!']
# ['25157', '3', '0', '3', '0', '1', 'we all went through so much shit together . I miss them bitches']
# ['25158', '3', '0', '0', '3', '2', 'we dem birds.']
# ['25159', '3', '0', '3', '0', '1', "we don't pay hoes... we don't save hoes"]
# ['25160', '3', '0', '3', '0', '1', 'we in here turn up turn up wheres the bitches']
# ['25161', '4', '0', '4', '0', '1', 'we live in a world where drake can steal your hoes and make fun of you, shit crazy']
# ['25162', '3', '0', '3', '0', '1', "we need to pile some hoes in the back of Ross' car"]
# ['25164', '6', '1', '5', '0', '1', "we'ont get head from hoes wit overbites.."]
# ['25165', '3', '0', '1', '2', '2', 'wearing pajamas tonight 4 da gook UDigg Grey day']
# ['25166', '9', '0', '8', '1', '1', 'weeknd makes songs for the hoes']
# ['25167', '6', '0', '6', '0', '1', "well ain't that a bitch"]
# ['25168', '3', '1', '2', '0', '1', "well i want to be Victoria's Secret dyke angel&#128124;&#128149;"]
# ['25169', '3', '0', '0', '3', '2', "were gunna shake our honkey tonk badonkadonks (': @SAMMI_boyden"]
# ['25170', '3', '1', '2', '0', '1', 'what a broke niggah gone tell her.']
# ['25171', '3', '0', '0', '3', '2', 'what a clam shame']
# ['25172', '3', '0', '2', '1', '1', 'what a hoe']
# ['25173', '3', '0', '3', '0', '1', 'what a little bitch lol']
# ['25174', '3', '1', '2', '0', '1', 'what a retard lol']
# ['25175', '3', '0', '3', '0', '1', 'what he was clearly stating to the masses is....pussy is to be shared...so girl send out dat pussy to my shark']
# ['25176', '3', '0', '3', '0', '1', 'what to do when your ear hurts like a bitch?']
# ['25177', '6', '1', '5', '0', '1', "what's wrong with bitches fuck nigga"]
# ['25178', '3', '1', '2', '0', '1', 'when Em said "I\'m on my straight grizzly, so why would I buy you a gay ass teddy bear bitch youre already bi-polar." http://t.co/FQquXTxHBo']
# ['25179', '3', '0', '3', '0', '1', 'when a bitch say you cant dance http://t.co/GKZj7QNDIF']
# ['25180', '3', '0', '3', '0', '1', "when ah rich nigga want ur bitch it's nothing u can do... but hope she think about u on dem shopping sprees..."]
# ['25181', '3', '0', '1', '2', '2', 'when baylor wins im talking so much trash']
# ['25182', '3', '0', '3', '0', '1', 'when bitches be tryna wash their shit on the low lol funny af']
# ['25183', '3', '0', '3', '0', '1', 'when bitches change and start acting like the nigga they with &lt;&lt;&lt;&lt;&lt;&lt;']
# ['25184', '3', '0', '3', '0', '1', "when bitches u hate won't stop staring at u in the halls http://t.co/OjNXhoIGdw"]
# ['25185', '6', '0', '6', '0', '1', 'when im there with a ghetto ass accent being shy as hell like']
# ['25186', '3', '0', '3', '0', '1', 'when nino said "cancel that bitch ill buy a new one" &gt;&gt;&gt;&gt;&gt;&gt;&gt;&gt;&gt;&gt;&gt;']
# ['25187', '3', '0', '3', '0', '1', 'when the dude shoots his jiz in the bitches eye in silence of the lambs']
# ['25188', '3', '0', '3', '0', '1', 'when ya name gain weight ya ex bitches cant let go']
# ['25189', '6', '0', '6', '0', '1', "when ya name gain weight ya ex hoes can't let go"]
# ['25190', '3', '0', '2', '1', '1', 'when yo song come on and you hit the blunt hard af cause that hoe go dat hard']
# ['25191', '3', '0', '3', '0', '1', 'when you first walked in the door at that party you saw a big booty hoe &#8212; Name ? http://t.co/JERsrSwhUe']
# ['25192', '3', '1', '2', '0', '1', "when you're stupid, you don't know it. life is so easy. have you ever seen a depressed retard? i envy that."]
# ['25193', '3', '0', '3', '0', '1', 'where da ratchet hoes at?']
# ['25194', '3', '0', '3', '0', '1', 'where my scene hoes at?']
# ['25195', '3', '0', '3', '0', '1', "where r the fun twins at @TheJsimps I'm trying to lick cheeto dust and coleslaw off your nips"]
# ['25196', '6', '0', '6', '0', '1', 'whheeet bitch you LYING']
# ['25197', '3', '2', '1', '0', '0', 'which one of these names is more offensive kike, wop, kraut, wetback jigaboo, towelhead, gook, or redskin.']
# ['25198', '3', '0', '3', '0', '1', "which twitter bitch isn't selling chokers&#10068;&#10068;"]
# ['25199', '4', '0', '1', '3', '2', "who's downie like a brownie 4 brunch? Need mimosas"]
# ['25200', '3', '0', '3', '0', '1', "who's pussy better then a crazy bitch?"]
# ['25201', '3', '0', '2', '1', '1', "why are people acting like they didn't know hoe allen was going to the cavs 6 months ago?"]
# ['25202', '3', '1', '2', '0', '1', 'why are these freshman so ghetto lmao']
# ['25203', '3', '0', '3', '0', '1', 'why bitches gotta be bitches']
# ['25204', '3', '0', '3', '0', '1', 'why cant girls just admit that they want the dick as much as us guys want the pussy? human nature duhh']
# ['25205', '3', '0', '3', '0', '1', 'why did the fins sign finnegan? hes a certified bitch']
# ['25206', '3', '0', '3', '0', '1', 'why do hoes think its a good idea to air out their dirty laundry at a public place? bitch im tryna enjoy my burrito']
# ['25207', '3', '0', '2', '1', '1', 'why do little scrawny white boys play ghetto rap music while they walk around.']
# ['25208', '3', '0', '3', '0', '1', "why even get pregnant by someone that isn't an never will be fit to be a dad, smh stupid stupid hoes"]
# ['25209', '3', '1', '2', '0', '1', 'why is this thirsty white basic ass bitch still talking to me gtfo']
# ['25210', '3', '0', '3', '0', '1', "why lie tho&#8230;&#8230; we gon' find you bitches"]
# ['25211', '3', '0', '3', '0', '1', 'why niggas put heart eyes under everybody pictures? &#128553; then it be them poo la la hoes.']
# ['25212', '3', '0', '3', '0', '1', "why should there be an age limit on movies?it ain't their fault if a 13yr old is traumatized from an R rates filmbunch of pussies"]
# ['25213', '6', '1', '5', '0', '1', "why tf is this bitch in my class wearing all brewers shit it's football season,,,,"]
# ['25214', '3', '0', '3', '0', '1', 'why the fuck did twitter move the new tweet box to above the feed lol it looks fucking retarded']
# ['25215', '3', '0', '0', '3', '2', 'why they playing trash on ESPN right now.']
# ['25216', '3', '0', '3', '0', '1', "why you act like a little booshie bitch now, that's why you don't have friends hoe"]
# ['25217', '6', '2', '4', '0', '1', 'why you think ol niggas wit no money dont even care about swag, rockin sandals wit velcor straps, they aint checkin for bitches']
# ['25218', '3', '0', '3', '0', '1', 'whys this bitch wearing a striped tshirt and nike shocks']
# ['25219', '3', '1', '2', '0', '1', 'will u love dat nigga even if he lose it all... or will u dip like the groupie hoes searching for another &#11088;&#65039;']
# ['25220', '3', '0', '3', '0', '1', 'will u sell dat pussy for me?']
# ['25221', '3', '0', '0', '3', '2', 'wish I had a brownie or a dab to knock me out rn']
# ['25222', '3', '0', '2', '1', '1', 'wishing I could high five whoever named a species of birds "great tits"']
# ['25223', '3', '0', '0', '3', '2', 'with Louisville (5) losing last night, a win to #iubb (7) tonight should have them back in the top 5! #ncaa #basketball #iu #hoosiers']
# ['25224', '3', '0', '3', '0', '1', 'women hate hoes becuz they fuckin up the economy']
# ['25226', '3', '1', '2', '0', '1', 'wonder if they gon have em for the low on nigger friday....']
# ['25227', '3', '0', '0', '3', '2', 'wondertrade is the best pokemon feature ever. i just got a level 27 japanese wobbuffet for a level 4 beginning area trash pokemon']
# ['25228', '3', '0', '3', '0', '1', 'worst thing a bitch can do &#8220;@loyalshawn: Bitches main reason for being in another nigga face is to get they nigga jealous . &#128078; Wack .&#8221;']
# ['25229', '3', '0', '3', '0', '1', "wouldn't be such a bitch if people didn't piss me off 24/7"]
# ['25230', '3', '0', '3', '0', '1', 'wow im a bitch????? nice to fucking know.']
# ['25231', '3', '0', '3', '0', '1', 'wow im gonna smoke myself retarded when i get home']
# ['25232', '3', '1', '2', '0', '1', 'wow! RT @Tendilkar: RT @LyricalSunset: RT @LilMissCuntCake: Some bitches just deserve to get punched. In the vagina.']
# ['25233', '3', '0', '3', '0', '1', 'wow.... a bird just shitted on me']
# ['25234', '3', '0', '0', '3', '2', 'wth is that playing missy? ........ i mean seriously? RT @mr_republicann: This movie gone be trash http://t.co/8BIppVUvzr']
# ['25235', '3', '0', '3', '0', '1', 'wut spook me even more is its gon be dark when nigga drive outta hea..... im sick already']
# ['25236', '3', '0', '3', '0', '1', 'x_x RT @LaDarinAintShit: Fat bitches with normal sized legs be looking like car keys.']
# ['25237', '3', '0', '3', '0', '1', 'y give a bitch an inch when she rather have 9']
# ['25238', '3', '0', '3', '0', '1', "y'all I'm so mad I wasted them calories on that honey bun.. that ho was dry as hell &#128553;"]
# ['25239', '6', '0', '5', '1', '1', "y'all hoes avoid schemes"]
# ['25240', '3', '0', '3', '0', '1', "y'all moms was hoes with no morals so i ain't surprised"]
# ['25241', '3', '1', '2', '0', '1', "y'all remember that tall ass dyke named Jay??? Lmfaooo"]
# ['25242', '6', '2', '4', '0', '1', 'ya bitch aint bad nigga, you aint got no taste']
# ['25243', '3', '0', '3', '0', '1', 'ya girl pussy is trash as fuck.']
# ['25244', '3', '1', '2', '0', '1', "ya'll niggers have a good thanksgiving"]
# ['25245', '3', '1', '2', '0', '1', 'yal some faggots yup nigga you n you fuckin fruit cups.']
# ['25246', '3', '1', '2', '0', '1', 'yall crazy hoes need jesus lol']
# ['25247', '3', '0', '3', '0', '1', 'yall pussies i swur']
# ['25248', '3', '0', '0', '3', '2', 'yay I like when jacob has colored layouts']
# ['25249', '3', '0', '0', '3', '2', 'yaya ho.. cute avi tho RT @ViVaLa_Ari I had no idea she was sleep &#128553;']
# ['25250', '3', '0', '1', '2', '2', "yea so about @N_tel 's new friend.. all my friends kno they're only allowed one cute darkie friend n that's me! lol"]
# ['25251', '3', '0', '3', '0', '1', "yeah I'm a bitch, but guess what? you're still a slut."]
# ['25252', '3', '0', '3', '0', '1', "yeah I'm small den a hoe http://t.co/VV3qdTo7MG"]
# ['25253', '3', '1', '2', '0', '1', 'yeah i got soul i was brought up by colored women.']
# ['25254', '3', '0', '3', '0', '1', 'yeah these valley faggots can go fuck themselves']
# ['25255', '3', '1', '2', '0', '1', 'yes good shapely eurotrash manbooty']
# ['25256', '3', '0', '3', '0', '1', 'yet this nigga still checkin up on his old hoes.....']
# ['25257', '3', '0', '3', '0', '1', 'yo bitch bitch gone let me fuck tonightthursty Thursday at the WesGod cave']
# ['25258', '3', '0', '3', '0', '1', 'yo bitch look like a boogawolf']
# ['25259', '3', '0', '3', '0', '1', 'yo bitch want that vitamin D she lookin desperate']
# ['25260', '6', '0', '6', '0', '1', 'yo bitch whippin in the early morning']
# ['25261', '3', '0', '3', '0', '1', 'yo hoe will get slayed . &#128298;&#128298;']
# ['25262', '3', '1', '2', '0', '1', 'yo hoe will get slayed! &#128298;']
# ['25263', '3', '0', '3', '0', '1', 'you a hoe nigga forreal']
# ['25264', '3', '2', '1', '0', '0', 'you a pussy ass nigga and I know it nigga.']
# ['25265', '6', '1', '5', '0', '1', "you ain't a real nigga without goal a to chase and a yellow bone bitch w/ some toes to paint"]
# ['25266', '3', '1', '2', '0', '1', "you ain't gotta be a dyke to like hoes"]
# ['25267', '3', '0', '3', '0', '1', 'you are a hoe, hoe, &amp; a hoe.']
# ['25268', '3', '0', '3', '0', '1', 'you bitches love yall some corny nigga']
# ['25269', '3', '0', '3', '0', '1', 'you can masturbate anytime bitch lol &#8220;@greyyygoose: I just want some damn alone time. Fucccckkkkkk! Lol&#8221;']
# ['25270', '3', '0', '3', '0', '1', 'you can never get a group of hoes together witout em resorting to being hoes....']
# ['25271', '3', '0', '3', '0', '1', 'you can tell when dick recently been in a pussy, taste nasty af ewww bitches better never play that shit']
# ['25272', '3', '0', '3', '0', '1', "you can't cuff a hoe lmao"]
# ['25273', '3', '0', '2', '1', '1', 'you drove me redneck crazy']
# ['25274', '3', '0', '3', '0', '1', 'you fake niggah lolol']
# ['25275', '3', '1', '2', '0', '1', 'you got niggas, and i got bitches.']
# ['25276', '3', '0', '2', '1', '1', 'you gotta be a new breed of retarded if you do that. http://t.co/PeinRwsZzq']
# ['25277', '3', '0', '3', '0', '1', 'you gotta understand that these bitches are childish']
# ['25278', '3', '0', '3', '0', '1', 'you hoe spice']
# ['25279', '3', '0', '3', '0', '1', 'you just want some attention hoe']
# ['25280', '3', '0', '1', '2', '2', 'you know what they say, the early bird gets the worm. *puts gummy worms in your morning coffee*']
# ['25281', '3', '0', '3', '0', '1', 'you know what your doing when you favorite a tweet, tryna cheat ass bitch haha']
# ['25282', '3', '0', '3', '0', '1', "you lil dumb ass bitch, i ain't fuckin wit chu!.. i got a million, trillion things i'd rather fuckin' do.. than to be fuckin witchu."]
# ['25283', '3', '0', '3', '0', '1', "you look like AC Green...bitch don't call here anymore..."]
# ['25284', '3', '0', '3', '0', '1', 'you look like your 12 stop talking about fucking bitches &#9757;']
# ['25285', '3', '0', '3', '0', '1', 'you might as well gone pussy pop on a stage']
# ['25286', '3', '1', '2', '0', '1', "you niggers cheat on ya gf's? smh...."]
# ['25287', '3', '0', '3', '0', '1', 'you really care bout dis bitch. my dick all in yo feelings']
# ['25288', '3', '0', '3', '0', '1', 'you worried bout other bitches, you need me for?']
# ['25289', '3', '3', '0', '0', '0', "you're all niggers"]
# ['25290', '3', '2', '1', '0', '0', "you're such a retard i hope you get type 2 diabetes and die from a sugar rush you fucking faggot @Dare_ILK"]
# ['25291', '3', '0', '2', '1', '1', "you's a muthaf***in lie &#8220;@LifeAsKing: @20_Pearls @corey_emanuel right! His TL is trash &#8230;. Now, mine? Bible scriptures and hymns&#8221;"]
# ['25292', '3', '0', '1', '2', '2', "you've gone and broke the wrong heart baby, and drove me redneck crazy"]
# ['25294', '3', '0', '3', '0', '1', 'young buck wanna eat!!.. dat nigguh like I aint fuckin dis up again']
# ['25295', '6', '0', '6', '0', '1', 'youu got wild bitches tellin you lies']
# ['25296', '3', '0', '0', '3', '2', '~~Ruffled | Ntac Eileen Dahlia - Beautiful color combination of pink, orange, yellow &amp; white. A Coll http://t.co/H0dYEBvnZB']

# %%
import tweepy
import numpy as np
import pandas as pd
import string
import re
from textblob import TextBlob
from io import StringIO
import nltk
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
import csv
import requests
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# Make an HTTP GET request to the CSV URL and get the response text

# %%
response = requests.get(csv_url).text

# Create a pandas DataFrame from the response text using StringIO
df = pd.read_csv(StringIO(response))

# Print the first few rows of the DataFrame
print(df.head())
# Out:
#    Unnamed: 0  count  hate_speech  offensive_language  neither  class  \
# 0           0      3            0                   0        3      2
# 1           1      3            0                   3        0      1
# 2           2      3            0                   3        0      1
# 3           3      3            0                   2        1      1
# 4           4      6            0                   6        0      1
#
#                                                tweet
# 0  !!! RT @mayasolovely: As a woman you shouldn't...
# 1  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...

# %%
df["labels"] = df["class"].map({0: "Hate Speech", 
                                    1: "Offensive Language", 
                                    2: "No Hate and Offensive"})
print(df.head())
# Out:
#    Unnamed: 0  count  hate_speech  offensive_language  neither  class  \
# 0           0      3            0                   0        3      2
# 1           1      3            0                   3        0      1
# 2           2      3            0                   3        0      1
# 3           3      3            0                   2        1      1
# 4           4      6            0                   6        0      1
#
#                                                tweet                 labels
# 0  !!! RT @mayasolovely: As a woman you shouldn't...  No Hate and Offensive
# 1  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...     Offensive Language
# 2  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...     Offensive Language
# 3  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...     Offensive Language
# 4  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...     Offensive Language

# %%
df = df[["tweet", "labels"]]
print(df.head())
# Out:
#                                                tweet                 labels
# 0  !!! RT @mayasolovely: As a woman you shouldn't...  No Hate and Offensive
# 1  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...     Offensive Language
# 2  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...     Offensive Language
# 3  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...     Offensive Language
# 4  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...     Offensive Language

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# Define a function to clean the tweets
def clean(text):
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)
    text = text.lower()
    text = " ".join(text.split())
    stopwords_set = set(stopwords.words('english'))
    stemmer = SnowballStemmer('english')
    text = [word for word in text.split(' ') if word not in stopwords_set]
    text=" ".join(text)
    text = [stemmer.stem(word) for word in text.split(' ')]
    text=" ".join(text)
    return text

# Apply the clean function to the tweets column of the DataFrame
df["tweet"] = df["tweet"].apply(clean)

# %% [markdown]
# Now let’s split the dataset into training and test sets and train a machine learning model for the task of hate speech detection:

# %%
x = np.array(df["tweet"])
y = np.array(df["labels"])

cv = CountVectorizer()
X = cv.fit_transform(x) # Fit the Data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

clf = DecisionTreeClassifier()
clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# Now let’s test this machine learning model to see if it detects hate speech or not:

# %%
sample = "true but then again I'm my opinion a hoe is someone who goes and sleeps with everybody"
data = cv.transform([sample]).toarray()
print(clf.predict(data))
# Out:
# ['Offensive Language']
